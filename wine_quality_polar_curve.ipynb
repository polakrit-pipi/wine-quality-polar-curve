# %% [markdown]
# <a href="https://colab.research.google.com/github/polakrit-pipi/wine-quality-polar-curve/blob/main/wine_quality_polar_curve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Set up and Download Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import plotly.graph_objects as go
import numpy as np

# %%
df_wine_fully=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTJepe4dn5w2dTsfexdOiGG7pm3kqGC_yLn4Iy4E0E9q6DjnLAHaT7hHyH_9YwgbWvlIltvEgd8MNHH/pub?gid=367699842&single=true&output=csv")

# %% [markdown]
# # **Data Prepraration**

# %%
df_wine_fully
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### **drop quality column**

# %%
df_wine_drop_ph = df_wine_fully.drop(['quality','pH','density'], axis=1)
df_wine_drop_ph
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_wine = df_wine_fully.drop(['quality'],axis=1)
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
quality = df_wine_fully[["quality"]]
quality
# Out:
#      quality
# 0        bad
# 1        bad
# 2        bad
# 3       good
# 4        bad
# ...      ...
# 1594     bad
# 1595    good
# 1596    good
# 1597     bad
# 1598    good
#
# [1599 rows x 1 columns]

# %%
df_wine.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# dtype: int64

# %%
scaler = MinMaxScaler()
scaler.fit(df_wine_drop_ph)
data_scale = pd.DataFrame(scaler.transform(df_wine_drop_ph), columns=df_wine_drop_ph.columns)
data_scale
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260         0.00        0.068493   0.106845
# 1          0.283186          0.520548         0.00        0.116438   0.143573
# 2          0.283186          0.438356         0.04        0.095890   0.133556
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 4          0.247788          0.397260         0.00        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 1594       0.141593          0.328767         0.08        0.075342   0.130217
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1597       0.115044          0.359589         0.12        0.075342   0.105175
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %%
inertia = []
for i in range(1,16):
    kmeans = KMeans(
        n_clusters=i, init="k-means++"
    )
    kmeans.fit(data_scale)
    inertia.append(kmeans.inertia_)
plt.plot(range(1, 16), inertia, color='red', marker='x')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f86f03066cd2> in <module>()
#       4         n_clusters=i, init="k-means++"
#       5     )
# ----> 6     kmeans.fit(data_scale)
#       7     inertia.append(kmeans.inertia_)
#       8 plt.plot(range(1, 16), inertia, color='red', marker='x')
#
# NameError: name 'data_scale' is not defined

# %%
kmeans4 = KMeans(
        n_clusters=4, init="k-means++"
    )

# %%
kmeans4.fit(data_scale)
# Out:
# KMeans(n_clusters=4)

# %%
kmeans4.n_features_in_
# Out:
# 9

# %%
kmeans4.feature_names_in_
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'sulphates', 'alcohol'], dtype=object)

# %%
kmeans4.inertia_
# Out:
# 149.37322148869077

# %%
kmeans4.labels_
# Out:
# array([2, 2, 2, ..., 0, 0, 3], dtype=int32)

# %%
kmeans4.cluster_centers_
# Out:
# array([[0.18706981, 0.30539248, 0.12821429, 0.09893455, 0.09682142,
#         0.23971607, 0.12005721, 0.19213953, 0.50838421],
#        [0.48947928, 0.18678347, 0.4888412 , 0.11840055, 0.14159508,
#         0.13416551, 0.0817953 , 0.23868572, 0.37166282],
#        [0.2660924 , 0.35752513, 0.11927757, 0.08907365, 0.12593232,
#         0.14535693, 0.10734391, 0.16226862, 0.21653505],
#        [0.31307491, 0.266448  , 0.31109859, 0.14795485, 0.12628559,
#         0.38200754, 0.29244015, 0.19492283, 0.23224991]])

# %%
kmeans4.predict(data_scale) #START DEPLOYMENT
# Out:
# array([2, 2, 2, ..., 0, 0, 3], dtype=int32)

# %%
data_scale['group'] = kmeans4.predict(data_scale)
data_scale
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260         0.00        0.068493   0.106845
# 1          0.283186          0.520548         0.00        0.116438   0.143573
# 2          0.283186          0.438356         0.04        0.095890   0.133556
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 4          0.247788          0.397260         0.00        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 1594       0.141593          0.328767         0.08        0.075342   0.130217
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1597       0.115044          0.359589         0.12        0.075342   0.105175
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %%
data_scale['group'].value_counts()
# Out:
# 2    526
# 1    466
# 3    355
# 0    252
# Name: group, dtype: int64

# %%
scale_group = data_scale.groupby("group").mean().reset_index()
scale_group
# Out:
#    group  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      0       0.187070          0.305392     0.128214        0.098935
# 1      1       0.489479          0.186783     0.488841        0.118401
# 2      2       0.266092          0.357525     0.119278        0.089074
# 3      3       0.313075          0.266448     0.311099        0.147955
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  sulphates   alcohol
# 0   0.096821             0.239716              0.120057   0.192140  0.508384
# 1   0.141595             0.134166              0.081795   0.238686  0.371663
# 2   0.125932             0.145357              0.107344   0.162269  0.216535
# 3   0.126286             0.382008              0.292440   0.194923  0.232250

# %%
polar = data_scale.groupby("group").mean().reset_index()
polar = pd.melt(polar,id_vars=["group"])
polar
# Out:
#     group              variable     value
# 0       0         fixed acidity  0.187070
# 1       1         fixed acidity  0.489479
# 2       2         fixed acidity  0.266092
# 3       3         fixed acidity  0.313075
# 4       0      volatile acidity  0.305392
# 5       1      volatile acidity  0.186783
# 6       2      volatile acidity  0.357525
# 7       3      volatile acidity  0.266448
# 8       0           citric acid  0.128214
# 9       1           citric acid  0.488841
# 10      2           citric acid  0.119278
# 11      3           citric acid  0.311099
# 12      0        residual sugar  0.098935
# 13      1        residual sugar  0.118401
# 14      2        residual sugar  0.089074
# 15      3        residual sugar  0.147955
# 16      0             chlorides  0.096821
# 17      1             chlorides  0.141595
# 18      2             chlorides  0.125932
# 19      3             chlorides  0.126286
# 20      0   free sulfur dioxide  0.239716
# ...

# %%
fig_all = px.line_polar(polar, r="value", theta="variable", color="group", line_close=True, height=600, width=600)
fig_all.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(rows=2, cols=2, 
              specs=[[{'type': 'polar'}]*2]*2)
lab = 0
for i in range(1,3):
    for j in range(1,3):
        fig.add_trace(go.Scatterpolar(
        name = f"Cluster Group {lab}",
        r = polar[polar.group == lab]['value'], 
        theta =polar[polar.group == lab]["variable"],
        # mode = 'lines'
        ), i, j)
        lab += 1
fig.update_layout(height=900, width=1200, title_text="Cluster Polar Plot",showlegend=True)
fig.update_traces(fill='toself')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Data preparation_New**

# %%
df_wine_drop_ph["group"] = kmeans4.labels_
df_wine_drop_ph
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_wine_drop_ph["quality"] = quality
df_wine_drop_ph
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_wine_drop_ph[df_wine_drop_ph["quality"]=="good"].group.value_counts()
# Out:
# 1    342
# 0    197
# 2    188
# 3    128
# Name: group, dtype: int64

# %%
df_wine_drop_ph[df_wine_drop_ph["quality"]=="bad"].group.value_counts()
# Out:
# 2    338
# 3    227
# 1    124
# 0     55
# Name: group, dtype: int64

# %%
pd.DataFrame(df_wine_drop_ph[df_wine_drop_ph["quality"]=="bad"].group.value_counts().to_list(), columns=["Bad"])
# Out:
#    Bad
# 0  338
# 1  227
# 2  124
# 3   55

# %%
pd.DataFrame(df_wine_drop_ph[df_wine_drop_ph["quality"]=="good"].group.value_counts().to_list(), columns=["Good"]) #Return a list of the values.
# Out:
#    Good
# 0   342
# 1   197
# 2   188
# 3   128

# %%
# datagroup_0 = df_wine_drop_ph[df_wine_drop_ph["group"]==0]
# datagroup_1 = df_wine_drop_ph[df_wine_drop_ph["group"]==1]
# datagroup_2 = df_wine_drop_ph[df_wine_drop_ph["group"]==2]
# datagroup_3 = df_wine_drop_ph[df_wine_drop_ph["group"]==3]

# %%
 df_wine_drop_ph.groupby("group").mean().reset_index()
# Out:
#    group  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      0       6.713889          0.565873     0.128214        2.344444
# 1      1      10.131116          0.392704     0.488841        2.628648
# 2      2       7.606844          0.641987     0.119278        2.200475
# 3      3       8.137746          0.509014     0.311099        3.060141
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  sulphates    alcohol
# 0   0.069996            18.019841             39.976190   0.650873  11.704497
# 1   0.096815            10.525751             29.148069   0.728605  10.815808
# 2   0.087433            11.320342             36.378327   0.600989   9.807478
# 3   0.087645            28.122535             88.760563   0.655521   9.909624
